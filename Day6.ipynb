# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhakal1997/30dayDataScience/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Data
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
        'Age': [28, 24, 35, 32]}

# Bar plot using Matplotlib
plt.bar(data['Name'], data['Age'])
plt.title('Age Distribution')
plt.xlabel('Name')
plt.ylabel('Age')
plt.show()

# Seaborn heatmap example
import numpy as np
corr_matrix = np.random.rand(4,4)
sns.heatmap(corr_matrix, annot=True)
plt.title('Sample Heatmap')
plt.show()
